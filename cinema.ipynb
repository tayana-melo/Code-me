# %% [markdown]
# # Análise de Dados de Filmes exibidos no Brasil de 2009 a 2017
# Com base nos dados da Ancine https://oca.ancine.gov.br/cinema vamos analisar os filmes no Brasil
#
# Arquivo--> 2102_0.xlsx

# %%
# Impoortando as bibliotecas
import pandas as pd
# Configurando o matplolib
# %matplotlib inline

# %%
# Criar o DataFrame com base no arquivo Excel
# Precisamos pular as 2 primeiras linhas (skiprows)
df= pd.read_excel("2102_0.xlsx", skiprows=2, skipfooter=16)

# Exibindo as 5 primeiras Linhas do DataFrame
df.head()
# Out:
#   Ano de Lançamento Certificado de Produto Brasileiro (CPB)  \
# 0              1995                          B0400064200000
# 1              1995                          B0500310700000
# 2              1995                          B0500264600000
# 3              1995                                       -
# 4              1995                          B0300012900000
#
#                                     Título                    Direção  \
# 0                          A Causa Secreta             Sérgio Bianchi
# 1     Carlota Joaquina, Princesa do Brazil             Carla Camurati
# 2  Carmen Miranda - Bananas is my Business             Helena Solberg
# 3                       Cinema de Lágrimas  Nelson Pereira dos Santos
# 4                              Efeito Ilha       Luiz Alberto Pereira
#
#          Gênero Empresa Produtora Brasileira Majoritária  UF  \
# 0        Ficção        Agravo Produções Cinematográficas  SP
# ...

# %%
# Exibindo as 5 últimas Linhas do DataFrame
df.tail(20)
# Out:
#                                       Ano de Lançamento  \
# 1578                                                NaN
# 1579                                             Notas:
# 1580                                                NaN
# 1581  1.      Empresa Produtora Brasileira Majoritár...
# 1582  a.   Nos casos em que a informação sobre cota ...
# 1583  b.   Nos casos em que não havia a informação d...
# 1584  c.    Nos casos de mais uma produtora majoritá...
# 1585  d.   Nos casos em que não havia CPB, foi consi...
# 1586  e.   Nos casos em que não havia CPB e Salic, f...
# 1587                                                NaN
# 1588  2.      Empresa Produtora Minoritária Brasilei...
# 1589  a.   Em caso de mais de uma empresa produtora ...
# 1590  b.   Nos casos em que o percentual era igual, ...
# 1591                                                NaN
# 1592  3.      Para o nome das empresas produtoras fo...
# 1593                                                NaN
# ...
